# %%
! python train_models.py
# Out:
# Iniciando entrenamiento de modelos...
# 2025/09/06 19:29:20 INFO mlflow.tracking.fluent: Experiment with name 'hospital_admissions_prediction_set3' does not exist. Creating a new experiment.
#
# ...
# ENTRENANDO CON FEATURE SET 3
# ...
# Datos cargados: 88489 muestras, 19 características
# Divisiones: Train=53093, Val=17698, Test=17698
#
# --- Entrenando lightgbm ---
# /Users/danieltrujillo/Documents/MAIA/2025-21-Proyecto-Desarrollo de Soluciones/2025-2-ProyectoFinal/maia-proyecto_calidad_aire/.venv/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/danieltrujillo/Documents/MAIA/2025-21-Proyecto-Desarrollo de Soluciones/2025-2-ProyectoFinal/maia-proyecto_calidad_aire/.venv/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# ...
